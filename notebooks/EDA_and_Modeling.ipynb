# %% [markdown]
# # Heart Disease EDA and Modeling
# Run the project scripts and use this notebook for screenshots/notes.

# %%
# !python ../src/data_acquisition.py
# !python ../src/eda.py
# !python ../src/train.py

# %% [markdown]
# Add your own observations here after running.
